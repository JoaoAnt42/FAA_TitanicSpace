# %%
from sklearn.model_selection import KFold
import numpy as np 
import pandas as pd 
from sklearn.preprocessing import StandardScaler
from catboost import CatBoostClassifier, Pool
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import joblib
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import cross_val_score, HalvingGridSearchCV
from sklearn.metrics import plot_roc_curve
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import cross_val_predict
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import roc_curve
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import roc_curve
from sklearn.metrics import precision_score, recall_score
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit

import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import warnings
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.compose import make_column_selector, make_column_transformer


warnings.filterwarnings('ignore')

# %%
def pandas_preprocessing(X, y_present=True):
  X['PassengerId_split'] = X['PassengerId'].apply(lambda x : str(x).split(sep = '_', maxsplit=1))
  X['Group']= X['PassengerId_split'].apply(lambda x : np.nan if x[0] == 'nan' else x[0])
  X['Group_id']= X['PassengerId_split'].apply(lambda x : np.nan if x[0] == 'nan' else x[1])
  X = X.drop(['PassengerId','PassengerId_split'],axis=1)

  # Split the names
  X['Name_split'] = X['Name'].apply(lambda x : str(x).split(sep = ' ', maxsplit=1))
  X['Surname']= X['Name_split'].apply(lambda x : np.nan if x[0] == 'nan' else x[1])
  X = X.drop(['Name','Name_split'],axis=1)

  # Split the cabins
  X['Cabin_splt'] = X['Cabin'].apply(lambda x : str(x).split(sep = '/'))
  X['Deck']= X['Cabin_splt'].apply(lambda x : np.nan if x[0] == 'nan' else x[0])
  X['CabinNumber']= X['Cabin_splt'].apply(lambda x : np.nan if x[0] == 'nan' else x[1]).astype('float')
  X['CabinSide']= X['Cabin_splt'].apply(lambda x : np.nan if x[0] == 'nan' else x[2])
  X = X.drop(['Cabin','Cabin_splt'],axis=1)

  # Create Total
  numeric_cols = list(X.select_dtypes(include = np.number).columns)
  X['Total'] = sum(X[col] for col in numeric_cols if col not in ["Age", "CabinNumber"])
  # X['age'] = pd.cut(x=X['Age'], bins=range(0, 90, 7))
  # X['total'] = pd.cut(x=X['Total'], bins=np.linspace(0, 50000, num=20))
  # X = X.drop(['Age', "Total"],axis=1)
  # X['age'] = X['age'].astype('str') 
  # X['total'] = X['total'].astype('str')
  target = X['Transported']
  target = target.astype(int)
  X = X.drop(['Transported'],axis=1)
  return X, target

# %%
bol_pipeline = make_pipeline(
    SimpleImputer(strategy="most_frequent"),
    )

cat_pipeline = make_pipeline(
    SimpleImputer(strategy="most_frequent"),
    OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1)
    )


num_pipeline = make_pipeline(
    SimpleImputer(strategy='median'),
    StandardScaler()
)

preprocessing_pipe = make_column_transformer(
    (num_pipeline, make_column_selector(dtype_include=np.number)),
    (cat_pipeline, make_column_selector(dtype_include=object)),
    (bol_pipeline, make_column_selector(dtype_include=bool)),
)

# %%
# %matplotlib inline

# %%
df = pd.read_csv('data_FAA/train.csv')
df, y = pandas_preprocessing(df)
df_prepared = preprocessing_pipe.fit_transform(df)

# %%
df_prepared_fr = pd.DataFrame(
    df_prepared,
    columns=preprocessing_pipe.get_feature_names_out(),
    index=df.index)
df_prepared_fr.head()
X_train, X_test, y_train, y_test = train_test_split(df_prepared_fr, y, test_size = 0.2, random_state = 100)

# %%
import joblib
with open('data_FAA/data2.pkl', 'wb') as f:
    joblib.dump([X_train, y_train, X_test, y_test], f)

# %%
X_train, y_train, X_test, y_test = joblib.load('data_FAA/data2.pkl')
redo_grid_search = 0
cm = 0

# %%
if redo_grid_search:
  pool_train = Pool(
      X_train,
      y_train
  )

  pool_test = Pool(
      X_test,
      y_test
  )

  search_parameters = {
      "learning_rate": [0.01, 0.1, 0.5],
      "iterations": [300, 400, 500, 600, 700, 1000],
      "depth": [4, 5, 6, 7, 8, 9, 10],
      "l2_leaf_reg": [1, 3, 5, 7, 9, 11]
  }

  cb_classifier = CatBoostClassifier(random_state=0xDEADBEEF, logging_level="Silent")

  best_params = cb_classifier.grid_search(
      search_parameters,
      X=pool_train,
      cv=3,
      verbose=15,
  #     plot=True
  )

  print(f"Best parameters:\n{best_params['params']}")
  print(f"Best score: {cb_classifier.get_best_score()}")
  cb_best = best_params.best_estimator_
else:
    cb_best = CatBoostClassifier(depth=7, l2_leaf_reg=11, iterations=300, learning_rate=0.1)
    print("Best score: {'learn': {'Logloss': 0.21473847818768485}}")
# Out:
# Best score: {'learn': {'Logloss': 0.21473847818768485}}

# %%
y_pred = cross_val_predict(cb_best, X_train, y_train, cv=20)
acc = accuracy_score(y_train, y_pred)
print(f"The accuracy score for this model is {acc}")
# Out:
# 0:	learn: 0.6358863	total: 64.5ms	remaining: 19.3s
# 1:	learn: 0.6034006	total: 67.7ms	remaining: 10.1s
# 2:	learn: 0.5722637	total: 70.8ms	remaining: 7s
# 3:	learn: 0.5470601	total: 73.9ms	remaining: 5.47s
# 4:	learn: 0.5321397	total: 77.1ms	remaining: 4.55s
# 5:	learn: 0.5190832	total: 80.2ms	remaining: 3.93s
# 6:	learn: 0.5083625	total: 83.5ms	remaining: 3.5s
# 7:	learn: 0.4980524	total: 86.7ms	remaining: 3.16s
# 8:	learn: 0.4882566	total: 89.9ms	remaining: 2.91s
# 9:	learn: 0.4804127	total: 93.3ms	remaining: 2.7s
# 10:	learn: 0.4728762	total: 96.3ms	remaining: 2.53s
# 11:	learn: 0.4652613	total: 99.7ms	remaining: 2.39s
# 12:	learn: 0.4599167	total: 102ms	remaining: 2.26s
# 13:	learn: 0.4558716	total: 105ms	remaining: 2.14s
# 14:	learn: 0.4504583	total: 108ms	remaining: 2.06s
# 15:	learn: 0.4456993	total: 112ms	remaining: 1.98s
# 16:	learn: 0.4419824	total: 115ms	remaining: 1.91s
# 17:	learn: 0.4372888	total: 117ms	remaining: 1.84s
# 18:	learn: 0.4336557	total: 120ms	remaining: 1.77s
# 19:	learn: 0.4308362	total: 123ms	remaining: 1.72s
# 20:	learn: 0.4287868	total: 126ms	remaining: 1.67s
# 21:	learn: 0.4261558	total: 128ms	remaining: 1.62s
# 22:	learn: 0.4231843	total: 131ms	remaining: 1.57s
# 23:	learn: 0.4210730	total: 133ms	remaining: 1.53s
# 24:	learn: 0.4185744	total: 135ms	remaining: 1.49s
# 25:	learn: 0.4168495	total: 138ms	remaining: 1.46s
# 26:	learn: 0.4137644	total: 141ms	remaining: 1.42s
# 27:	learn: 0.4117507	total: 143ms	remaining: 1.39s
# 28:	learn: 0.4100822	total: 146ms	remaining: 1.36s
# 29:	learn: 0.4084375	total: 148ms	remaining: 1.33s
# 30:	learn: 0.4071820	total: 150ms	remaining: 1.3s
# 31:	learn: 0.4054633	total: 152ms	remaining: 1.27s
# 32:	learn: 0.4037447	total: 154ms	remaining: 1.25s
# 33:	learn: 0.4024506	total: 156ms	remaining: 1.22s
# 34:	learn: 0.4005599	total: 159ms	remaining: 1.2s
# 35:	learn: 0.3984254	total: 161ms	remaining: 1.18s
# 36:	learn: 0.3964848	total: 163ms	remaining: 1.16s
# 37:	learn: 0.3939788	total: 165ms	remaining: 1.13s
# 38:	learn: 0.3928762	total: 167ms	remaining: 1.11s
# 39:	learn: 0.3914732	total: 169ms	remaining: 1.1s
# 40:	learn: 0.3904081	total: 171ms	remaining: 1.08s
# 41:	learn: 0.3890575	total: 174ms	remaining: 1.07s
# 42:	learn: 0.3872826	total: 177ms	remaining: 1.05s
# 43:	learn: 0.3859020	total: 180ms	remaining: 1.04s
# 44:	learn: 0.3848070	total: 182ms	remaining: 1.03s
# 45:	learn: 0.3841072	total: 184ms	remaining: 1.01s
# 46:	learn: 0.3834633	total: 186ms	remaining: 1s
# 47:	learn: 0.3827046	total: 189ms	remaining: 991ms
# 48:	learn: 0.3819609	total: 191ms	remaining: 978ms
# 49:	learn: 0.3809256	total: 193ms	remaining: 966ms
# 50:	learn: 0.3800855	total: 195ms	remaining: 954ms
# 51:	learn: 0.3786730	total: 198ms	remaining: 943ms
# 52:	learn: 0.3778716	total: 200ms	remaining: 933ms
# 53:	learn: 0.3767128	total: 203ms	remaining: 926ms
# 54:	learn: 0.3759189	total: 206ms	remaining: 917ms
# 55:	learn: 0.3753909	total: 209ms	remaining: 909ms
# 56:	learn: 0.3742874	total: 211ms	remaining: 899ms
# 57:	learn: 0.3733987	total: 213ms	remaining: 890ms
# 58:	learn: 0.3722197	total: 216ms	remaining: 882ms
# 59:	learn: 0.3712735	total: 218ms	remaining: 874ms
# 60:	learn: 0.3700432	total: 221ms	remaining: 866ms
# 61:	learn: 0.3694353	total: 224ms	remaining: 858ms
# 62:	learn: 0.3687881	total: 226ms	remaining: 851ms
# 63:	learn: 0.3677509	total: 229ms	remaining: 843ms
# 64:	learn: 0.3666474	total: 231ms	remaining: 835ms
# 65:	learn: 0.3658323	total: 234ms	remaining: 831ms
# 66:	learn: 0.3653999	total: 237ms	remaining: 825ms
# 67:	learn: 0.3647650	total: 239ms	remaining: 817ms
# 68:	learn: 0.3643642	total: 242ms	remaining: 809ms
# 69:	learn: 0.3635169	total: 244ms	remaining: 801ms
# 70:	learn: 0.3627437	total: 246ms	remaining: 793ms
# 71:	learn: 0.3620401	total: 248ms	remaining: 785ms
# 72:	learn: 0.3614518	total: 250ms	remaining: 777ms
# 73:	learn: 0.3603951	total: 252ms	remaining: 771ms
# 74:	learn: 0.3597963	total: 254ms	remaining: 763ms
# 75:	learn: 0.3583653	total: 256ms	remaining: 755ms
# 76:	learn: 0.3580667	total: 259ms	remaining: 750ms
# 77:	learn: 0.3573188	total: 261ms	remaining: 743ms
# 78:	learn: 0.3561685	total: 263ms	remaining: 736ms
# 79:	learn: 0.3556074	total: 265ms	remaining: 730ms
# 80:	learn: 0.3552163	total: 268ms	remaining: 724ms
# 81:	learn: 0.3543278	total: 270ms	remaining: 717ms
# 82:	learn: 0.3536225	total: 272ms	remaining: 711ms
# 83:	learn: 0.3526833	total: 274ms	remaining: 704ms
# 84:	learn: 0.3523077	total: 276ms	remaining: 699ms
# 85:	learn: 0.3520394	total: 278ms	remaining: 691ms
# 86:	learn: 0.3509874	total: 283ms	remaining: 692ms
# 87:	learn: 0.3503528	total: 286ms	remaining: 689ms
# 88:	learn: 0.3496095	total: 289ms	remaining: 686ms
# 89:	learn: 0.3491548	total: 292ms	remaining: 682ms
# 90:	learn: 0.3487193	total: 295ms	remaining: 677ms
# 91:	learn: 0.3482077	total: 298ms	remaining: 674ms
# 92:	learn: 0.3476111	total: 301ms	remaining: 669ms
# 93:	learn: 0.3464278	total: 303ms	remaining: 664ms
# 94:	learn: 0.3459498	total: 306ms	remaining: 660ms
# 95:	learn: 0.3449998	total: 309ms	remaining: 656ms
# 96:	learn: 0.3441171	total: 311ms	remaining: 651ms
# 97:	learn: 0.3436802	total: 314ms	remaining: 648ms
# 98:	learn: 0.3431724	total: 317ms	remaining: 644ms
# 99:	learn: 0.3427733	total: 319ms	remaining: 639ms
# 100:	learn: 0.3423700	total: 322ms	remaining: 634ms
# 101:	learn: 0.3417771	total: 324ms	remaining: 629ms
# 102:	learn: 0.3413104	total: 326ms	remaining: 624ms
# 103:	learn: 0.3406952	total: 329ms	remaining: 620ms
# 104:	learn: 0.3401297	total: 331ms	remaining: 615ms
# 105:	learn: 0.3391690	total: 333ms	remaining: 610ms
# 106:	learn: 0.3386818	total: 336ms	remaining: 605ms
# 107:	learn: 0.3381189	total: 338ms	remaining: 601ms
# 108:	learn: 0.3371996	total: 340ms	remaining: 596ms
# 109:	learn: 0.3367712	total: 342ms	remaining: 591ms
# 110:	learn: 0.3359468	total: 345ms	remaining: 587ms
# 111:	learn: 0.3351253	total: 347ms	remaining: 583ms
# 112:	learn: 0.3345025	total: 349ms	remaining: 578ms
# 113:	learn: 0.3337653	total: 352ms	remaining: 574ms
# 114:	learn: 0.3333727	total: 354ms	remaining: 569ms
# 115:	learn: 0.3324375	total: 355ms	remaining: 564ms
# 116:	learn: 0.3319053	total: 357ms	remaining: 559ms
# 117:	learn: 0.3314133	total: 359ms	remaining: 554ms
# 118:	learn: 0.3308372	total: 362ms	remaining: 551ms
# 119:	learn: 0.3303757	total: 364ms	remaining: 546ms
# 120:	learn: 0.3296083	total: 366ms	remaining: 542ms
# 121:	learn: 0.3291329	total: 369ms	remaining: 538ms
# 122:	learn: 0.3284436	total: 371ms	remaining: 534ms
# 123:	learn: 0.3280188	total: 373ms	remaining: 529ms
# 124:	learn: 0.3277640	total: 375ms	remaining: 526ms
# 125:	learn: 0.3267553	total: 378ms	remaining: 522ms
# 126:	learn: 0.3262443	total: 380ms	remaining: 518ms
# 127:	learn: 0.3253536	total: 383ms	remaining: 514ms
# 128:	learn: 0.3245161	total: 385ms	remaining: 510ms
# 129:	learn: 0.3240630	total: 387ms	remaining: 506ms
# 130:	learn: 0.3236588	total: 389ms	remaining: 501ms
# 131:	learn: 0.3230974	total: 391ms	remaining: 497ms
# 132:	learn: 0.3224386	total: 393ms	remaining: 494ms
# 133:	learn: 0.3218094	total: 395ms	remaining: 490ms
# 134:	learn: 0.3211932	total: 397ms	remaining: 486ms
# 135:	learn: 0.3203277	total: 399ms	remaining: 481ms
# 136:	learn: 0.3200371	total: 401ms	remaining: 477ms
# 137:	learn: 0.3196021	total: 403ms	remaining: 473ms
# 138:	learn: 0.3190970	total: 405ms	remaining: 469ms
# 139:	learn: 0.3185407	total: 407ms	remaining: 465ms
# 140:	learn: 0.3180254	total: 409ms	remaining: 461ms
# 141:	learn: 0.3174766	total: 411ms	remaining: 458ms
# 142:	learn: 0.3169049	total: 413ms	remaining: 454ms
# 143:	learn: 0.3161195	total: 415ms	remaining: 450ms
# 144:	learn: 0.3156931	total: 417ms	remaining: 446ms
# 145:	learn: 0.3153658	total: 419ms	remaining: 442ms
# 146:	learn: 0.3147378	total: 421ms	remaining: 438ms
# 147:	learn: 0.3144606	total: 424ms	remaining: 435ms
# 148:	learn: 0.3137431	total: 426ms	remaining: 431ms
# 149:	learn: 0.3130658	total: 428ms	remaining: 428ms
# 150:	learn: 0.3128507	total: 429ms	remaining: 424ms
# 151:	learn: 0.3120454	total: 431ms	remaining: 420ms
# 152:	learn: 0.3115753	total: 433ms	remaining: 416ms

# %%
from sklearn.metrics import RocCurveDisplay
cb_best.fit(X_train, y_train)
RocCurveDisplay.from_estimator(
   cb_best, X_test, y_test)

# %%
from sklearn.metrics import PrecisionRecallDisplay
PrecisionRecallDisplay.from_estimator(
   cb_best, X_test, y_test)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(2, 2, figsize=(12, 8))
RocCurveDisplay.from_estimator(
   cb_best, X_test, y_test, ax=ax[1, 1])


PrecisionRecallDisplay.from_estimator(
   cb_best, X_test, y_test, ax=ax[1, 0])

ConfusionMatrixDisplay.from_predictions(y_train, y_pred, ax=ax[0, 0])
ConfusionMatrixDisplay.from_predictions(y_train, y_pred, normalize="true", ax=ax[0, 1])
plt.show()

# %%
# %%time

# always use same RANDOM_STATE k-folds for comparability between tests, reproducibility
RANDOMSTATE = 42
np.random.seed(RANDOMSTATE)

kfolds = KFold(n_splits=20, shuffle=True, random_state=RANDOMSTATE)

MEAN_RESPONSE=y_train.mean()
def cv_to_raw(cv_val, mean_response=MEAN_RESPONSE):
    return np.expm1(mean_response+cv_val) - np.expm1(mean_response)
	
scores = -cross_val_score(cb_best, X_train, y_train,
                          scoring="neg_root_mean_squared_error",
                          cv=kfolds,
                          n_jobs=-1)
raw_scores = [cv_to_raw(x) for x in scores]
print("Raw CV RMSE %.0f (STD %.0f)" % (np.mean(raw_scores), np.std(raw_scores)))

# %%
max_scores = sum(score for score, name in zip(cb_best.feature_importances_, X_train.columns))

for score, name in zip(cb_best.feature_importances_, X_train.columns):
    print(f"{score/max_scores * 100:.1f}%{' ':>20}{name.split('__', 1)[1]:>20}")

# %%
train_sizes, train_scores, valid_scores = learning_curve(
    cb_best, X_train, y_train, train_sizes=np.linspace(0.01, 1.0, 40), cv=5,
    scoring="neg_root_mean_squared_error")
train_errors = -train_scores.mean(axis=1)
valid_errors = -valid_scores.mean(axis=1)

plt.figure(figsize=(6, 4))  # extra code – not needed, just formatting
plt.plot(train_sizes, train_errors, "r-+", linewidth=2, label="train")
plt.plot(train_sizes, valid_errors, "b-", linewidth=3, label="valid")

# extra code – beautifies and saves Figure 4–15
plt.xlabel("Training set size")
plt.ylabel("RMSE")
plt.grid()
plt.legend(loc="upper right")
# plt.axis([0, 1000, 0.3, 0.9])
# plt.save_fig("underfitting_learning_curves_plot")

plt.show()

# %%
#----------------For submission----------------
data1= pd.read_csv("data_FAA/train.csv")
data2 = pd.read_csv("data_FAA/evaluation.csv")
data2 = pd.read_csv("data_FAA/evaluation.csv")
data2['Transported'] =-1

data1, y1 = pandas_preprocessing(data1)
data2, y2 = pandas_preprocessing(data2)

data1 = preprocessing_pipe.fit_transform(data1)
data2 = preprocessing_pipe.transform(data2)

cb_best.fit(data1, y1)

pred = cb_best.predict(data2)

pred = pred.astype(bool)
result=pd.read_csv('data_FAA/sample_submission.csv')
result['Transported'] = pred
result.to_csv('submissions/submission_cat_nobins.csv', index=False)
